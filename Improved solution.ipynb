# %% [markdown]
# # Navigation Project

# %% [markdown]
# ## Section 1: Setup and Installation

# %% [markdown]
# This section sets up the environment by configuring paths and installing necessary packages.
# It ensures compatibility with the Unity ML-Agents environment and checks the NumPy version.

# %%
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/home/student/.local/bin"
os.environ['PATH'] = f"{os.environ['PATH']}:/opt/conda/lib/python3.10/site-packages"
os.environ['PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION'] = 'python'

# %%
# Check NumPy version
# !python -m pip freeze | grep numpy
# Out:
# numpy @ file:///work/mkl/numpy_and_numpy_base_1682953417311/work

# %%
# Install required packages quietly
# !pip -q install .

# %% [markdown]
# ## Section 2: Import Libraries

# %% [markdown]
# Imports all necessary libraries for the reinforcement learning task, including PyTorch for neural networks,
# NumPy for numerical operations, and Matplotlib for visualization.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import random
from collections import deque
from unityagents import UnityEnvironment
import time
import matplotlib.pyplot as plt

# %% [markdown]
# ## Section 3: Initialize Environment

# %% [markdown]
# Initializes the Unity ML-Agents Banana environment and extracts state and action space sizes.
# The environment is set to training mode for faster simulation.

# %%
env = UnityEnvironment(file_name="/data/Banana_Linux_NoVis/Banana.x86_64")
brain_name = env.brain_names[0]
brain = env.brains[brain_name]
state_size = 37  # Ray perceptions + velocity
action_size = 4  # Forward, backward, left, right
# Out:
# Found path: /data/Banana_Linux_NoVis/Banana.x86_64
# Mono path[0] = '/data/Banana_Linux_NoVis/Banana_Data/Managed'
# Mono config path = '/data/Banana_Linux_NoVis/Banana_Data/MonoBleedingEdge/etc'
# Preloaded 'libgrpc_csharp_ext.x64.so'
# Unable to preload the following plugins:
# 	libgrpc_csharp_ext.x86.so
# Logging to /home/student/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# ## Section 4: State and Action Space Explanation

# %% [markdown]
# State Space (37 dimensions):
# - 35 dimensions: Ray-based perception from 7 rays at angles [20, 90, 160, 45, 135, 70, 110].
#   Each ray returns 5 values: [Yellow Banana, Wall, Blue Banana, Agent, Distance].
# - 2 dimensions: Agent's velocity (left/right and forward/backward).
# - Fully observable, capturing all relevant information about obstacles and agent dynamics.
#
# Action Space (4 discrete actions):
# - 0: Move forward
# - 1: Move backward
# - 2: Turn left
# - 3: Turn right
#
# Objective:
# - Collect yellow bananas (+1 reward) while avoiding blue bananas (-1 reward).
# - Goal: Achieve an average score of +13 over 100 consecutive episodes.

# %% [markdown]
# ## Section 5: Dueling DQN Network

# %% [markdown]
# Defines the Dueling DQN architecture, which splits Q-values into value and advantage streams for
# improved value estimation.

# %%
class DuelingQNetwork(nn.Module):
    def __init__(self, state_size, action_size, seed):
        super(DuelingQNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc_value = nn.Linear(64, 1)          # Value stream
        self.fc_advantage = nn.Linear(64, action_size)  # Advantage stream

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        value = self.fc_value(x)
        advantage = self.fc_advantage(x)
        return value + advantage - advantage.mean()  # Combine streams

# %% [markdown]
# ## Section 6: Prioritized Replay Buffer

# %% [markdown]
# Implements a Prioritized Experience Replay buffer, which prioritizes experiences with higher
# TD errors for more efficient learning.

# %%
class PrioritizedReplayBuffer:
    def __init__(self, buffer_size, batch_size, seed, alpha=0.7, beta=0.5):
        self.buffer_size = buffer_size
        self.batch_size = batch_size
        # self.alpha = alpha  # Priority exponent (increased for more focus on high-error samples)
        self.alpha = 0.6  # Reduced for less extreme prioritization
        # self.beta = beta    # Importance sampling exponent (increased for stronger correction)
        self.beta = 0.4   # Starting value for annealing
        self.seed = random.seed(seed)
        self.memory = []
        self.priorities = []
        self.pos = 0

    def add(self, state, action, reward, next_state, done, priority):
        if len(self.memory) < self.buffer_size:
            self.memory.append(None)
            self.priorities.append(None)
        self.memory[self.pos] = (state, action, reward, next_state, done)
        self.priorities[self.pos] = priority
        self.pos = (self.pos + 1) % self.buffer_size

    def sample(self):
        if len(self.memory) < self.batch_size:
            return None
        priorities = np.array(self.priorities[:len(self.memory)], dtype=np.float32)
        probabilities = priorities ** self.alpha
        probabilities /= probabilities.sum()
        indices = np.random.choice(len(self.memory), self.batch_size, p=probabilities)
        experiences = [self.memory[idx] for idx in indices]
        states = torch.from_numpy(np.vstack([e[0] for e in experiences])).float()
        actions = torch.from_numpy(np.vstack([e[1] for e in experiences])).long()
        rewards = torch.from_numpy(np.vstack([e[2] for e in experiences])).float()
        next_states = torch.from_numpy(np.vstack([e[3] for e in experiences])).float()
        dones = torch.from_numpy(np.vstack([e[4] for e in experiences]).astype(np.uint8)).float()
        weights = (len(self.memory) * probabilities[indices]) ** (-self.beta)
        weights /= weights.max()
        return (states, actions, rewards, next_states, dones, indices, torch.from_numpy(weights).float())

    def update_priorities(self, indices, priorities):
        for idx, priority in zip(indices, priorities):
            self.priorities[idx] = priority + 1e-5  # Small constant to avoid zero priority

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ## Section 7: Agent Class

# %% [markdown]
# Defines the Agent, which uses Dueling DQN with PER, Double DQN, and multi-step learning for
# improved performance.

# %%
class Agent:
    def __init__(self, state_size, action_size, seed):
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)
        self.qnetwork_local = DuelingQNetwork(state_size, action_size, seed)
        self.qnetwork_target = DuelingQNetwork(state_size, action_size, seed)
        # self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr=0.0005)  # Reduced learning rate
        self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr=0.0001)  # Reduced for stability
        self.memory = PrioritizedReplayBuffer(buffer_size=100000, batch_size=128, seed=seed)
        self.t_step = 0
        self.n_step = 3  # Multi-step horizon
        self.gamma = 0.99  # Discount factor
        self.n_step_buffer = deque(maxlen=self.n_step)  # Buffer for n-step learning
        # new
        self.beta = 0.4  # Initial beta
        self.beta_increment = (1.0 - 0.4) / 1000  # Increment over 1000 episodes

    def step(self, state, action, reward, next_state, done):
        # Add single-step transition immediately
        priority = 1.0 if len(self.memory) == 0 else max(self.memory.priorities)
        self.n_step_buffer.append((state, action, reward, next_state, done))

        if len(self.n_step_buffer) == self.n_step or done:
            state, action, r, ns, d = self.n_step_buffer[0]
            total_reward = r
            if not d:
                for i in range(1, min(self.n_step, len(self.n_step_buffer))):
                    _, _, r, _, d = self.n_step_buffer[i]
                    total_reward += (self.gamma ** i) * r
                    if d:
                        ns = self.n_step_buffer[i][3]
                        break
                if not d and len(self.n_step_buffer) == self.n_step:
                    ns = self.n_step_buffer[-1][3]
            self.memory.add(state, action, total_reward, ns, d, priority)

        self.t_step = (self.t_step + 1) % 4
        if self.t_step == 0 and len(self.memory) >= 128:
            experiences = self.memory.sample()
            if experiences is not None:
                self.learn(experiences, self.gamma)

    def act(self, state, eps=0.):
        state = torch.from_numpy(state).float().unsqueeze(0)
        self.qnetwork_local.eval()
        with torch.no_grad():
            action_values = self.qnetwork_local(state)
        self.qnetwork_local.train()
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))

    def learn(self, experiences, gamma):
        states, actions, rewards, next_states, dones, indices, weights = experiences
        # Double DQN: Use local network to select actions, target network to evaluate
        _, max_actions = self.qnetwork_local(next_states).detach().max(1)
        Q_targets_next = self.qnetwork_target(next_states).detach().gather(1, max_actions.unsqueeze(1))
        Q_targets = rewards + (gamma ** self.n_step * Q_targets_next * (1 - dones))
        Q_expected = self.qnetwork_local(states).gather(1, actions)
        td_errors = Q_targets - Q_expected
        
        # Update beta each learning step
        self.beta = min(1.0, self.beta + self.beta_increment)
        self.memory.beta = self.beta  # Update buffer’s beta
        
        loss = (weights * td_errors ** 2).mean()
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.qnetwork_local.parameters(), 1.0)  # Clip gradients
        self.optimizer.step()
        # Update priorities based on TD error
        priorities = td_errors.detach().abs().squeeze().cpu().numpy()
        self.memory.update_priorities(indices, priorities)
        # Soft update target network with slightly higher tau
        #for target_param, local_param in zip(self.qnetwork_target.parameters(), self.qnetwork_local.parameters()):
        #   target_param.data.copy_(0.99 * target_param.data + 0.01 * local_param.data)
        tau = 0.001  # Slower update for stability
        for target_param, local_param in zip(self.qnetwork_target.parameters(), self.qnetwork_local.parameters()):
            target_param.data.copy_(tau * local_param.data + (1.0 - tau) * target_param.data)

# %% [markdown]
# ## Section 8: Training the Agent

# %% [markdown]
# Trains the agent using the improved Dueling DQN with Double DQN and multi-step learning.
# Saves model weights when the environment is solved and generates periodic progress plots.

# %%
# Initialize the agent
agent = Agent(state_size=state_size, action_size=action_size, seed=0)

# Training parameters
max_episodes = 2000
scores = []
avg_scores = []
scores_window = deque(maxlen=100)
eps = 1.0
eps_min = 0.01
eps_decay = 0.99  # Faster decay for quicker exploitation
start_time = time.time()

# Function to plot and save training progress
def plot_training_progress(scores, avg_scores, episode):
    plt.figure(figsize=(10, 5))
    episodes = range(1, len(scores) + 1)
    plt.plot(episodes, scores, label='Score per episode', alpha=0.5)
    plt.plot(episodes, avg_scores, label='Average over last 100 episodes', color='red')
    plt.axhline(y=13, color='green', linestyle='--', label='Target (13)')
    plt.xlabel('Episode')
    plt.ylabel('Score')
    plt.title(f'Training Progress up to Episode {episode}')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'training_progress_{episode}.png')
    plt.close()

# %%
# Training loop
for i_episode in range(1, max_episodes + 1):
    env_info = env.reset(train_mode=True)[brain_name]
    state = env_info.vector_observations[0]
    score = 0
    while True:
        action = agent.act(state, eps)
        env_info = env.step(action)[brain_name]
        next_state = env_info.vector_observations[0]
        reward = env_info.rewards[0]
        done = env_info.local_done[0]
        agent.step(state, action, reward, next_state, done)
        state = next_state
        score += reward
        if done:
            break
    scores.append(score)
    scores_window.append(score)
    # eps = max(eps_min, eps_decay * eps)
    #linear decay :
    eps = max(eps_min, 1.0 - (1.0 - eps_min) * (i_episode / 500))
    avg_score = np.mean(scores_window)
    avg_scores.append(avg_score)
    elapsed_time = time.time() - start_time
    print(f"Episode {i_episode}\tAverage Score: {avg_score:.2f}\tTime Elapsed: {elapsed_time:.2f} seconds")
    
    # Periodic plotting and checkpointing
    if i_episode % 100 == 0:
        print(f"\nEpisode {i_episode}\tAverage Score: {avg_score:.2f}\n")
        plot_training_progress(scores, avg_scores, i_episode)
        torch.save(agent.qnetwork_local.state_dict(), f'model_checkpoint_{i_episode}.pt')
    
    # Check if the environment is solved
    if avg_score >= 13.0 and len(scores_window) == 100:
        print(f"\nEnvironment solved in {i_episode} episodes!\tAverage Score: {avg_score:.2f}")
        torch.save(agent.qnetwork_local.state_dict(), 'model.pt')
        plot_training_progress(scores, avg_scores, i_episode)
        break
# Out:
# Episode 1	Average Score: 0.00	Time Elapsed: 6.87 seconds
# Episode 2	Average Score: 0.00	Time Elapsed: 15.56 seconds
# Episode 3	Average Score: 0.00	Time Elapsed: 24.17 seconds
# Episode 4	Average Score: 0.00	Time Elapsed: 33.16 seconds
# Episode 5	Average Score: 0.00	Time Elapsed: 42.17 seconds
# Episode 6	Average Score: -0.17	Time Elapsed: 51.26 seconds
# Episode 7	Average Score: -0.43	Time Elapsed: 59.86 seconds
# Episode 8	Average Score: -0.50	Time Elapsed: 69.08 seconds
# Episode 9	Average Score: -0.56	Time Elapsed: 78.18 seconds
# Episode 10	Average Score: -0.40	Time Elapsed: 86.97 seconds
# Episode 11	Average Score: -0.27	Time Elapsed: 95.38 seconds
# Episode 12	Average Score: -0.17	Time Elapsed: 104.38 seconds
# Episode 13	Average Score: -0.08	Time Elapsed: 113.67 seconds
# Episode 14	Average Score: -0.14	Time Elapsed: 122.58 seconds
# Episode 15	Average Score: -0.07	Time Elapsed: 131.87 seconds
# Episode 16	Average Score: 0.00	Time Elapsed: 140.68 seconds
# Episode 17	Average Score: 0.06	Time Elapsed: 149.56 seconds
# Episode 18	Average Score: 0.06	Time Elapsed: 158.87 seconds
# Episode 19	Average Score: 0.05	Time Elapsed: 168.07 seconds
# Episode 20	Average Score: 0.00	Time Elapsed: 177.27 seconds
# Episode 21	Average Score: 0.00	Time Elapsed: 186.67 seconds
# Episode 22	Average Score: 0.00	Time Elapsed: 196.16 seconds
# Episode 23	Average Score: 0.04	Time Elapsed: 205.37 seconds
# Episode 24	Average Score: 0.08	Time Elapsed: 214.98 seconds
# Episode 25	Average Score: 0.08	Time Elapsed: 224.06 seconds
# Episode 26	Average Score: 0.04	Time Elapsed: 233.48 seconds
# Episode 27	Average Score: 0.00	Time Elapsed: 242.27 seconds
# Episode 28	Average Score: 0.04	Time Elapsed: 250.86 seconds
# Episode 29	Average Score: 0.03	Time Elapsed: 260.17 seconds
# Episode 30	Average Score: 0.07	Time Elapsed: 269.48 seconds
# Episode 31	Average Score: 0.06	Time Elapsed: 279.26 seconds
# Episode 32	Average Score: 0.06	Time Elapsed: 289.36 seconds
# Episode 33	Average Score: 0.09	Time Elapsed: 298.96 seconds
# Episode 34	Average Score: 0.15	Time Elapsed: 308.37 seconds
# Episode 35	Average Score: 0.14	Time Elapsed: 317.27 seconds
# Episode 36	Average Score: 0.17	Time Elapsed: 325.98 seconds
# Episode 37	Average Score: 0.16	Time Elapsed: 334.68 seconds
# Episode 38	Average Score: 0.16	Time Elapsed: 343.17 seconds
# Episode 39	Average Score: 0.15	Time Elapsed: 351.68 seconds
# Episode 40	Average Score: 0.20	Time Elapsed: 360.47 seconds
# Episode 41	Average Score: 0.24	Time Elapsed: 369.46 seconds
# Episode 42	Average Score: 0.29	Time Elapsed: 378.17 seconds
# Episode 43	Average Score: 0.28	Time Elapsed: 387.08 seconds
# Episode 44	Average Score: 0.27	Time Elapsed: 395.96 seconds
# Episode 45	Average Score: 0.22	Time Elapsed: 404.86 seconds
# Episode 46	Average Score: 0.26	Time Elapsed: 413.86 seconds
# Episode 47	Average Score: 0.26	Time Elapsed: 422.67 seconds
# Episode 48	Average Score: 0.29	Time Elapsed: 431.87 seconds
# Episode 49	Average Score: 0.29	Time Elapsed: 441.07 seconds
# Episode 50	Average Score: 0.28	Time Elapsed: 450.17 seconds
# Episode 51	Average Score: 0.29	Time Elapsed: 459.26 seconds
# Episode 52	Average Score: 0.29	Time Elapsed: 468.36 seconds
# Episode 53	Average Score: 0.30	Time Elapsed: 478.38 seconds
# Episode 54	Average Score: 0.30	Time Elapsed: 488.38 seconds
# Episode 55	Average Score: 0.33	Time Elapsed: 498.07 seconds
# Episode 56	Average Score: 0.34	Time Elapsed: 507.76 seconds
# Episode 57	Average Score: 0.37	Time Elapsed: 517.36 seconds
# Episode 58	Average Score: 0.41	Time Elapsed: 526.38 seconds
# Episode 59	Average Score: 0.44	Time Elapsed: 535.76 seconds
# Episode 60	Average Score: 0.47	Time Elapsed: 544.88 seconds
# Episode 61	Average Score: 0.46	Time Elapsed: 554.66 seconds
# Episode 62	Average Score: 0.42	Time Elapsed: 564.66 seconds
# Episode 63	Average Score: 0.43	Time Elapsed: 574.18 seconds
# Episode 64	Average Score: 0.41	Time Elapsed: 584.07 seconds
# Episode 65	Average Score: 0.45	Time Elapsed: 593.78 seconds
# Episode 66	Average Score: 0.47	Time Elapsed: 603.38 seconds
# Episode 67	Average Score: 0.48	Time Elapsed: 613.18 seconds
# Episode 68	Average Score: 0.47	Time Elapsed: 623.28 seconds
# Episode 69	Average Score: 0.46	Time Elapsed: 633.58 seconds
# Episode 70	Average Score: 0.46	Time Elapsed: 643.46 seconds
# Episode 71	Average Score: 0.45	Time Elapsed: 652.97 seconds
# Episode 72	Average Score: 0.46	Time Elapsed: 662.77 seconds
# Episode 73	Average Score: 0.47	Time Elapsed: 672.57 seconds
# Episode 74	Average Score: 0.50	Time Elapsed: 682.28 seconds
# Episode 75	Average Score: 0.51	Time Elapsed: 691.56 seconds
# Episode 76	Average Score: 0.51	Time Elapsed: 701.06 seconds
# Episode 77	Average Score: 0.52	Time Elapsed: 710.67 seconds
# Episode 78	Average Score: 0.53	Time Elapsed: 720.28 seconds
# Episode 79	Average Score: 0.53	Time Elapsed: 730.06 seconds
# Episode 80	Average Score: 0.54	Time Elapsed: 739.88 seconds
# Episode 81	Average Score: 0.58	Time Elapsed: 749.58 seconds
# Episode 82	Average Score: 0.56	Time Elapsed: 759.58 seconds
# Episode 83	Average Score: 0.58	Time Elapsed: 769.38 seconds
# Episode 84	Average Score: 0.56	Time Elapsed: 779.06 seconds
# Episode 85	Average Score: 0.58	Time Elapsed: 788.78 seconds
# Episode 86	Average Score: 0.58	Time Elapsed: 798.86 seconds
# Episode 87	Average Score: 0.59	Time Elapsed: 809.08 seconds
# Episode 88	Average Score: 0.58	Time Elapsed: 818.77 seconds
# Episode 89	Average Score: 0.55	Time Elapsed: 828.38 seconds
# Episode 90	Average Score: 0.56	Time Elapsed: 838.16 seconds
# Episode 91	Average Score: 0.55	Time Elapsed: 847.76 seconds
# Episode 92	Average Score: 0.57	Time Elapsed: 857.56 seconds
# Episode 93	Average Score: 0.55	Time Elapsed: 867.26 seconds
# Episode 94	Average Score: 0.54	Time Elapsed: 876.96 seconds
# Episode 95	Average Score: 0.55	Time Elapsed: 886.47 seconds
# Episode 96	Average Score: 0.54	Time Elapsed: 896.18 seconds
# Episode 97	Average Score: 0.55	Time Elapsed: 905.86 seconds
# Episode 98	Average Score: 0.55	Time Elapsed: 915.66 seconds
# Episode 99	Average Score: 0.59	Time Elapsed: 925.36 seconds
# Episode 100	Average Score: 0.59	Time Elapsed: 934.98 seconds
#
# Episode 100	Average Score: 0.59
#
# Episode 101	Average Score: 0.59	Time Elapsed: 944.59 seconds
# Episode 102	Average Score: 0.60	Time Elapsed: 953.98 seconds
# Episode 103	Average Score: 0.61	Time Elapsed: 963.76 seconds
# Episode 104	Average Score: 0.62	Time Elapsed: 973.86 seconds
# Episode 105	Average Score: 0.62	Time Elapsed: 983.49 seconds
# Episode 106	Average Score: 0.66	Time Elapsed: 993.08 seconds
# Episode 107	Average Score: 0.69	Time Elapsed: 1002.56 seconds
# Episode 108	Average Score: 0.71	Time Elapsed: 1012.17 seconds
# Episode 109	Average Score: 0.73	Time Elapsed: 1021.96 seconds
# Episode 110	Average Score: 0.70	Time Elapsed: 1032.18 seconds
# Episode 111	Average Score: 0.69	Time Elapsed: 1042.08 seconds
# Episode 112	Average Score: 0.67	Time Elapsed: 1051.86 seconds
# Episode 113	Average Score: 0.68	Time Elapsed: 1061.86 seconds
# Episode 114	Average Score: 0.70	Time Elapsed: 1071.96 seconds
# Episode 115	Average Score: 0.69	Time Elapsed: 1081.98 seconds
# Episode 116	Average Score: 0.69	Time Elapsed: 1092.06 seconds
# Episode 117	Average Score: 0.69	Time Elapsed: 1102.39 seconds
# Episode 118	Average Score: 0.69	Time Elapsed: 1112.76 seconds
# Episode 119	Average Score: 0.72	Time Elapsed: 1122.98 seconds
# Episode 120	Average Score: 0.77	Time Elapsed: 1132.99 seconds
# Episode 121	Average Score: 0.79	Time Elapsed: 1143.26 seconds
# Episode 122	Average Score: 0.81	Time Elapsed: 1153.68 seconds
# Episode 123	Average Score: 0.81	Time Elapsed: 1163.89 seconds
# Episode 124	Average Score: 0.82	Time Elapsed: 1174.28 seconds
# Episode 125	Average Score: 0.84	Time Elapsed: 1184.67 seconds
# Episode 126	Average Score: 0.85	Time Elapsed: 1194.96 seconds
# Episode 127	Average Score: 0.89	Time Elapsed: 1205.36 seconds
# Episode 128	Average Score: 0.89	Time Elapsed: 1215.56 seconds
# Episode 129	Average Score: 0.89	Time Elapsed: 1225.46 seconds
# Episode 130	Average Score: 0.89	Time Elapsed: 1235.68 seconds
# Episode 131	Average Score: 0.91	Time Elapsed: 1245.86 seconds
# Episode 132	Average Score: 0.92	Time Elapsed: 1255.99 seconds
# Episode 133	Average Score: 0.91	Time Elapsed: 1265.88 seconds
# Episode 134	Average Score: 0.93	Time Elapsed: 1276.18 seconds
# Episode 135	Average Score: 0.92	Time Elapsed: 1286.39 seconds
# Episode 136	Average Score: 0.91	Time Elapsed: 1296.36 seconds
# Episode 137	Average Score: 0.93	Time Elapsed: 1306.66 seconds
# Episode 138	Average Score: 0.96	Time Elapsed: 1316.87 seconds
# Episode 139	Average Score: 0.97	Time Elapsed: 1327.18 seconds
# Episode 140	Average Score: 0.96	Time Elapsed: 1337.79 seconds
# Episode 141	Average Score: 0.95	Time Elapsed: 1348.16 seconds
# Episode 142	Average Score: 0.97	Time Elapsed: 1358.19 seconds
# Episode 143	Average Score: 0.99	Time Elapsed: 1368.56 seconds
# Episode 144	Average Score: 1.01	Time Elapsed: 1378.78 seconds
# Episode 145	Average Score: 1.05	Time Elapsed: 1389.09 seconds
# Episode 146	Average Score: 1.06	Time Elapsed: 1399.26 seconds
# Episode 147	Average Score: 1.06	Time Elapsed: 1409.69 seconds
# Episode 148	Average Score: 1.09	Time Elapsed: 1420.36 seconds
# Episode 149	Average Score: 1.08	Time Elapsed: 1430.68 seconds
# Episode 150	Average Score: 1.10	Time Elapsed: 1440.98 seconds
# Episode 151	Average Score: 1.14	Time Elapsed: 1451.49 seconds
# Episode 152	Average Score: 1.13	Time Elapsed: 1461.79 seconds
# Episode 153	Average Score: 1.12	Time Elapsed: 1471.98 seconds
# Episode 154	Average Score: 1.15	Time Elapsed: 1482.18 seconds
# Episode 155	Average Score: 1.14	Time Elapsed: 1492.66 seconds
# Episode 156	Average Score: 1.18	Time Elapsed: 1503.16 seconds
# Episode 157	Average Score: 1.20	Time Elapsed: 1513.48 seconds
# Episode 158	Average Score: 1.19	Time Elapsed: 1523.86 seconds
# Episode 159	Average Score: 1.18	Time Elapsed: 1534.06 seconds
# Episode 160	Average Score: 1.20	Time Elapsed: 1544.56 seconds
# Episode 161	Average Score: 1.23	Time Elapsed: 1555.08 seconds
# Episode 162	Average Score: 1.29	Time Elapsed: 1565.47 seconds
# Episode 163	Average Score: 1.32	Time Elapsed: 1576.17 seconds
# Episode 164	Average Score: 1.36	Time Elapsed: 1586.86 seconds
# Episode 165	Average Score: 1.35	Time Elapsed: 1597.27 seconds
# Episode 166	Average Score: 1.34	Time Elapsed: 1607.76 seconds
# Episode 167	Average Score: 1.36	Time Elapsed: 1618.28 seconds
# Episode 168	Average Score: 1.39	Time Elapsed: 1628.68 seconds
# Episode 169	Average Score: 1.40	Time Elapsed: 1639.26 seconds
# Episode 170	Average Score: 1.43	Time Elapsed: 1650.09 seconds
# Episode 171	Average Score: 1.47	Time Elapsed: 1660.66 seconds
# Episode 172	Average Score: 1.49	Time Elapsed: 1671.38 seconds
# Episode 173	Average Score: 1.49	Time Elapsed: 1682.09 seconds
# Episode 174	Average Score: 1.47	Time Elapsed: 1692.66 seconds
# Episode 175	Average Score: 1.45	Time Elapsed: 1703.58 seconds
# Episode 176	Average Score: 1.48	Time Elapsed: 1714.28 seconds
# Episode 177	Average Score: 1.53	Time Elapsed: 1725.08 seconds
# Episode 178	Average Score: 1.54	Time Elapsed: 1735.69 seconds
# Episode 179	Average Score: 1.53	Time Elapsed: 1746.38 seconds
# Episode 180	Average Score: 1.54	Time Elapsed: 1757.19 seconds
# Episode 181	Average Score: 1.49	Time Elapsed: 1767.96 seconds
# Episode 182	Average Score: 1.51	Time Elapsed: 1778.46 seconds
# Episode 183	Average Score: 1.52	Time Elapsed: 1789.49 seconds
# Episode 184	Average Score: 1.52	Time Elapsed: 1800.56 seconds
# Episode 185	Average Score: 1.48	Time Elapsed: 1811.48 seconds
# Episode 186	Average Score: 1.50	Time Elapsed: 1822.39 seconds
# Episode 187	Average Score: 1.54	Time Elapsed: 1833.29 seconds
# Episode 188	Average Score: 1.54	Time Elapsed: 1843.98 seconds
# Episode 189	Average Score: 1.55	Time Elapsed: 1854.78 seconds
# Episode 190	Average Score: 1.53	Time Elapsed: 1865.67 seconds
# Episode 191	Average Score: 1.53	Time Elapsed: 1876.76 seconds
# Episode 192	Average Score: 1.56	Time Elapsed: 1887.48 seconds
# Episode 193	Average Score: 1.57	Time Elapsed: 1898.46 seconds
# Episode 194	Average Score: 1.62	Time Elapsed: 1909.16 seconds
# Episode 195	Average Score: 1.61	Time Elapsed: 1920.09 seconds
# Episode 196	Average Score: 1.60	Time Elapsed: 1931.06 seconds
# Episode 197	Average Score: 1.62	Time Elapsed: 1941.86 seconds
# Episode 198	Average Score: 1.62	Time Elapsed: 1952.76 seconds
# Episode 199	Average Score: 1.60	Time Elapsed: 1963.68 seconds
# Episode 200	Average Score: 1.60	Time Elapsed: 1974.66 seconds
#
# Episode 200	Average Score: 1.60
#
# Episode 201	Average Score: 1.64	Time Elapsed: 1985.96 seconds
# Episode 202	Average Score: 1.66	Time Elapsed: 1996.99 seconds
# Episode 203	Average Score: 1.68	Time Elapsed: 2007.89 seconds
# Episode 204	Average Score: 1.71	Time Elapsed: 2018.89 seconds
# Episode 205	Average Score: 1.70	Time Elapsed: 2029.96 seconds
# Episode 206	Average Score: 1.68	Time Elapsed: 2040.66 seconds
# Episode 207	Average Score: 1.73	Time Elapsed: 2051.86 seconds
# Episode 208	Average Score: 1.74	Time Elapsed: 2062.88 seconds
# Episode 209	Average Score: 1.74	Time Elapsed: 2073.89 seconds
# Episode 210	Average Score: 1.78	Time Elapsed: 2085.08 seconds
# Episode 211	Average Score: 1.80	Time Elapsed: 2095.99 seconds
# Episode 212	Average Score: 1.82	Time Elapsed: 2106.86 seconds
# Episode 213	Average Score: 1.80	Time Elapsed: 2118.09 seconds
# Episode 214	Average Score: 1.78	Time Elapsed: 2129.09 seconds
# Episode 215	Average Score: 1.79	Time Elapsed: 2140.36 seconds
# Episode 216	Average Score: 1.86	Time Elapsed: 2151.39 seconds
# Episode 217	Average Score: 1.96	Time Elapsed: 2162.38 seconds
# Episode 218	Average Score: 1.99	Time Elapsed: 2173.66 seconds
# Episode 219	Average Score: 1.97	Time Elapsed: 2184.69 seconds
# Episode 220	Average Score: 1.97	Time Elapsed: 2195.86 seconds
# Episode 221	Average Score: 1.97	Time Elapsed: 2207.06 seconds
# Episode 222	Average Score: 1.96	Time Elapsed: 2218.26 seconds
# Episode 223	Average Score: 1.98	Time Elapsed: 2229.29 seconds
# Episode 224	Average Score: 2.00	Time Elapsed: 2240.46 seconds
# Episode 225	Average Score: 2.03	Time Elapsed: 2251.59 seconds
# Episode 226	Average Score: 2.09	Time Elapsed: 2262.79 seconds
# Episode 227	Average Score: 2.09	Time Elapsed: 2273.86 seconds
# Episode 228	Average Score: 2.11	Time Elapsed: 2284.86 seconds
# Episode 229	Average Score: 2.12	Time Elapsed: 2295.99 seconds
# Episode 230	Average Score: 2.12	Time Elapsed: 2307.26 seconds
# Episode 231	Average Score: 2.13	Time Elapsed: 2318.66 seconds
# Episode 232	Average Score: 2.16	Time Elapsed: 2329.79 seconds
# Episode 233	Average Score: 2.19	Time Elapsed: 2340.89 seconds
# Episode 234	Average Score: 2.20	Time Elapsed: 2352.09 seconds
# Episode 235	Average Score: 2.19	Time Elapsed: 2363.19 seconds
# Episode 236	Average Score: 2.21	Time Elapsed: 2374.36 seconds
# Episode 237	Average Score: 2.32	Time Elapsed: 2385.39 seconds
# Episode 238	Average Score: 2.33	Time Elapsed: 2396.49 seconds
# Episode 239	Average Score: 2.33	Time Elapsed: 2408.19 seconds
# Episode 240	Average Score: 2.40	Time Elapsed: 2420.46 seconds
# Episode 241	Average Score: 2.41	Time Elapsed: 2432.19 seconds
# Episode 242	Average Score: 2.40	Time Elapsed: 2444.50 seconds
# Episode 243	Average Score: 2.40	Time Elapsed: 2456.46 seconds
# Episode 244	Average Score: 2.42	Time Elapsed: 2468.06 seconds
# Episode 245	Average Score: 2.45	Time Elapsed: 2479.76 seconds
# Episode 246	Average Score: 2.48	Time Elapsed: 2491.26 seconds
# Episode 247	Average Score: 2.52	Time Elapsed: 2502.76 seconds
# Episode 248	Average Score: 2.47	Time Elapsed: 2514.70 seconds
# Episode 249	Average Score: 2.55	Time Elapsed: 2526.56 seconds
# Episode 250	Average Score: 2.59	Time Elapsed: 2538.10 seconds
# Episode 251	Average Score: 2.61	Time Elapsed: 2550.06 seconds
# Episode 252	Average Score: 2.65	Time Elapsed: 2561.86 seconds
# Episode 253	Average Score: 2.69	Time Elapsed: 2573.67 seconds
# Episode 254	Average Score: 2.69	Time Elapsed: 2585.49 seconds
# Episode 255	Average Score: 2.71	Time Elapsed: 2597.36 seconds
# Episode 256	Average Score: 2.72	Time Elapsed: 2608.99 seconds
# Episode 257	Average Score: 2.72	Time Elapsed: 2620.69 seconds
# Episode 258	Average Score: 2.77	Time Elapsed: 2632.29 seconds
# Episode 259	Average Score: 2.76	Time Elapsed: 2643.76 seconds
# Episode 260	Average Score: 2.78	Time Elapsed: 2655.46 seconds
# Episode 261	Average Score: 2.78	Time Elapsed: 2667.26 seconds
# Episode 262	Average Score: 2.78	Time Elapsed: 2678.96 seconds
# Episode 263	Average Score: 2.79	Time Elapsed: 2690.66 seconds
# Episode 264	Average Score: 2.80	Time Elapsed: 2702.49 seconds
# Episode 265	Average Score: 2.85	Time Elapsed: 2713.90 seconds
# Episode 266	Average Score: 2.89	Time Elapsed: 2726.00 seconds
# Episode 267	Average Score: 2.93	Time Elapsed: 2738.00 seconds
# Episode 268	Average Score: 2.95	Time Elapsed: 2749.86 seconds
# Episode 269	Average Score: 2.99	Time Elapsed: 2761.56 seconds
# Episode 270	Average Score: 3.04	Time Elapsed: 2773.28 seconds
# Episode 271	Average Score: 3.06	Time Elapsed: 2785.00 seconds
# Episode 272	Average Score: 3.09	Time Elapsed: 2796.96 seconds
# Episode 273	Average Score: 3.09	Time Elapsed: 2808.60 seconds
# Episode 274	Average Score: 3.11	Time Elapsed: 2820.46 seconds
# Episode 275	Average Score: 3.17	Time Elapsed: 2832.36 seconds
# Episode 276	Average Score: 3.18	Time Elapsed: 2843.99 seconds
# Episode 277	Average Score: 3.14	Time Elapsed: 2855.39 seconds
# Episode 278	Average Score: 3.15	Time Elapsed: 2866.80 seconds
# Episode 279	Average Score: 3.21	Time Elapsed: 2878.76 seconds
# Episode 280	Average Score: 3.24	Time Elapsed: 2890.60 seconds
# Episode 281	Average Score: 3.28	Time Elapsed: 2902.00 seconds
# Episode 282	Average Score: 3.31	Time Elapsed: 2913.56 seconds
# Episode 283	Average Score: 3.28	Time Elapsed: 2924.86 seconds
# Episode 284	Average Score: 3.35	Time Elapsed: 2936.26 seconds
# Episode 285	Average Score: 3.47	Time Elapsed: 2947.66 seconds
# Episode 286	Average Score: 3.46	Time Elapsed: 2958.88 seconds
# Episode 287	Average Score: 3.47	Time Elapsed: 2970.19 seconds
# Episode 288	Average Score: 3.51	Time Elapsed: 2981.70 seconds
# Episode 289	Average Score: 3.57	Time Elapsed: 2993.37 seconds
# Episode 290	Average Score: 3.61	Time Elapsed: 3004.79 seconds
# Episode 291	Average Score: 3.67	Time Elapsed: 3016.16 seconds
# Episode 292	Average Score: 3.66	Time Elapsed: 3027.76 seconds
# Episode 293	Average Score: 3.69	Time Elapsed: 3039.20 seconds
# Episode 294	Average Score: 3.68	Time Elapsed: 3050.76 seconds
# Episode 295	Average Score: 3.72	Time Elapsed: 3062.08 seconds
# Episode 296	Average Score: 3.78	Time Elapsed: 3073.66 seconds
# Episode 297	Average Score: 3.79	Time Elapsed: 3085.40 seconds
# Episode 298	Average Score: 3.82	Time Elapsed: 3096.89 seconds
# Episode 299	Average Score: 3.87	Time Elapsed: 3108.49 seconds
# Episode 300	Average Score: 3.95	Time Elapsed: 3120.26 seconds
#
# Episode 300	Average Score: 3.95
#
# Episode 301	Average Score: 3.93	Time Elapsed: 3131.89 seconds
# Episode 302	Average Score: 3.90	Time Elapsed: 3143.17 seconds
# Episode 303	Average Score: 3.89	Time Elapsed: 3154.86 seconds
# Episode 304	Average Score: 3.87	Time Elapsed: 3166.46 seconds
# Episode 305	Average Score: 3.96	Time Elapsed: 3177.86 seconds
# Episode 306	Average Score: 4.01	Time Elapsed: 3189.30 seconds
# Episode 307	Average Score: 3.97	Time Elapsed: 3200.76 seconds
# Episode 308	Average Score: 4.00	Time Elapsed: 3212.46 seconds
# Episode 309	Average Score: 4.05	Time Elapsed: 3223.96 seconds
# Episode 310	Average Score: 4.05	Time Elapsed: 3235.36 seconds
# Episode 311	Average Score: 4.09	Time Elapsed: 3247.09 seconds
# Episode 312	Average Score: 4.11	Time Elapsed: 3258.99 seconds
# Episode 313	Average Score: 4.18	Time Elapsed: 3271.16 seconds
# Episode 314	Average Score: 4.27	Time Elapsed: 3282.90 seconds
# Episode 315	Average Score: 4.35	Time Elapsed: 3294.66 seconds
# Episode 316	Average Score: 4.36	Time Elapsed: 3306.56 seconds
# Episode 317	Average Score: 4.33	Time Elapsed: 3318.36 seconds
# Episode 318	Average Score: 4.38	Time Elapsed: 3330.36 seconds
# Episode 319	Average Score: 4.46	Time Elapsed: 3344.26 seconds
# Episode 320	Average Score: 4.46	Time Elapsed: 3357.40 seconds
# Episode 321	Average Score: 4.49	Time Elapsed: 3370.76 seconds
# Episode 322	Average Score: 4.59	Time Elapsed: 3383.80 seconds
# Episode 323	Average Score: 4.63	Time Elapsed: 3396.80 seconds
# Episode 324	Average Score: 4.66	Time Elapsed: 3409.76 seconds
# Episode 325	Average Score: 4.63	Time Elapsed: 3421.96 seconds
# Episode 326	Average Score: 4.61	Time Elapsed: 3434.20 seconds
# Episode 327	Average Score: 4.68	Time Elapsed: 3446.20 seconds
# Episode 328	Average Score: 4.69	Time Elapsed: 3458.06 seconds
# Episode 329	Average Score: 4.75	Time Elapsed: 3470.90 seconds
# Episode 330	Average Score: 4.84	Time Elapsed: 3483.27 seconds
# Episode 331	Average Score: 4.87	Time Elapsed: 3497.00 seconds
# Episode 332	Average Score: 4.91	Time Elapsed: 3510.86 seconds
# Episode 333	Average Score: 4.91	Time Elapsed: 3522.76 seconds
# Episode 334	Average Score: 4.92	Time Elapsed: 3535.36 seconds
# Episode 335	Average Score: 4.99	Time Elapsed: 3548.26 seconds
# Episode 336	Average Score: 5.11	Time Elapsed: 3560.49 seconds
# Episode 337	Average Score: 5.02	Time Elapsed: 3572.86 seconds
# Episode 338	Average Score: 5.05	Time Elapsed: 3586.46 seconds
# Episode 339	Average Score: 5.11	Time Elapsed: 3599.80 seconds
# Episode 340	Average Score: 5.09	Time Elapsed: 3613.20 seconds
# Episode 341	Average Score: 5.14	Time Elapsed: 3627.66 seconds
# Episode 342	Average Score: 5.12	Time Elapsed: 3641.17 seconds
# Episode 343	Average Score: 5.11	Time Elapsed: 3654.56 seconds
# Episode 344	Average Score: 5.14	Time Elapsed: 3667.66 seconds
# Episode 345	Average Score: 5.16	Time Elapsed: 3681.17 seconds
# Episode 346	Average Score: 5.20	Time Elapsed: 3694.76 seconds
# Episode 347	Average Score: 5.21	Time Elapsed: 3706.90 seconds
# Episode 348	Average Score: 5.31	Time Elapsed: 3720.46 seconds
# Episode 349	Average Score: 5.28	Time Elapsed: 3733.26 seconds
# Episode 350	Average Score: 5.29	Time Elapsed: 3745.60 seconds
# Episode 351	Average Score: 5.32	Time Elapsed: 3759.26 seconds
# Episode 352	Average Score: 5.34	Time Elapsed: 3772.26 seconds
# Episode 353	Average Score: 5.32	Time Elapsed: 3784.46 seconds
# Episode 354	Average Score: 5.33	Time Elapsed: 3797.68 seconds
# Episode 355	Average Score: 5.38	Time Elapsed: 3810.47 seconds
# Episode 356	Average Score: 5.40	Time Elapsed: 3822.97 seconds
# Episode 357	Average Score: 5.39	Time Elapsed: 3835.36 seconds
# Episode 358	Average Score: 5.36	Time Elapsed: 3847.08 seconds
# Episode 359	Average Score: 5.44	Time Elapsed: 3858.80 seconds
# Episode 360	Average Score: 5.47	Time Elapsed: 3871.06 seconds
# Episode 361	Average Score: 5.50	Time Elapsed: 3883.00 seconds
# Episode 362	Average Score: 5.55	Time Elapsed: 3894.56 seconds
# Episode 363	Average Score: 5.57	Time Elapsed: 3906.16 seconds
# Episode 364	Average Score: 5.56	Time Elapsed: 3917.90 seconds
# Episode 365	Average Score: 5.56	Time Elapsed: 3929.77 seconds
# Episode 366	Average Score: 5.61	Time Elapsed: 3942.06 seconds
# Episode 367	Average Score: 5.67	Time Elapsed: 3955.10 seconds
# Episode 368	Average Score: 5.71	Time Elapsed: 3967.66 seconds
# Episode 369	Average Score: 5.73	Time Elapsed: 3980.17 seconds
# Episode 370	Average Score: 5.70	Time Elapsed: 3992.36 seconds
# Episode 371	Average Score: 5.74	Time Elapsed: 4004.60 seconds
# Episode 372	Average Score: 5.80	Time Elapsed: 4016.56 seconds
# Episode 373	Average Score: 5.84	Time Elapsed: 4028.76 seconds
# Episode 374	Average Score: 5.89	Time Elapsed: 4041.26 seconds
# Episode 375	Average Score: 5.91	Time Elapsed: 4053.96 seconds
# Episode 376	Average Score: 5.91	Time Elapsed: 4066.69 seconds
# Episode 377	Average Score: 5.93	Time Elapsed: 4080.16 seconds
# Episode 378	Average Score: 6.01	Time Elapsed: 4094.46 seconds
# Episode 379	Average Score: 6.03	Time Elapsed: 4106.36 seconds
# Episode 380	Average Score: 6.08	Time Elapsed: 4118.56 seconds
# Episode 381	Average Score: 6.11	Time Elapsed: 4130.36 seconds
# Episode 382	Average Score: 6.17	Time Elapsed: 4142.09 seconds
# Episode 383	Average Score: 6.25	Time Elapsed: 4153.49 seconds
# Episode 384	Average Score: 6.26	Time Elapsed: 4167.06 seconds
# Episode 385	Average Score: 6.23	Time Elapsed: 4179.86 seconds
# Episode 386	Average Score: 6.30	Time Elapsed: 4191.90 seconds
# Episode 387	Average Score: 6.32	Time Elapsed: 4204.58 seconds
# Episode 388	Average Score: 6.34	Time Elapsed: 4217.96 seconds
# Episode 389	Average Score: 6.39	Time Elapsed: 4230.79 seconds
# Episode 390	Average Score: 6.48	Time Elapsed: 4243.06 seconds
# Episode 391	Average Score: 6.50	Time Elapsed: 4255.36 seconds
# Episode 392	Average Score: 6.53	Time Elapsed: 4268.36 seconds
# Episode 393	Average Score: 6.62	Time Elapsed: 4280.49 seconds
# Episode 394	Average Score: 6.75	Time Elapsed: 4293.27 seconds
# Episode 395	Average Score: 6.75	Time Elapsed: 4305.76 seconds
# Episode 396	Average Score: 6.77	Time Elapsed: 4318.06 seconds
# Episode 397	Average Score: 6.80	Time Elapsed: 4331.76 seconds
# Episode 398	Average Score: 6.89	Time Elapsed: 4344.97 seconds
# Episode 399	Average Score: 6.92	Time Elapsed: 4357.46 seconds
# Episode 400	Average Score: 6.90	Time Elapsed: 4370.46 seconds
#
# Episode 400	Average Score: 6.90
# Episode 401	Average Score: 6.94	Time Elapsed: 4382.66 seconds
# Episode 402	Average Score: 7.07	Time Elapsed: 4394.46 seconds
# Episode 403	Average Score: 7.15	Time Elapsed: 4407.26 seconds
# Episode 404	Average Score: 7.21	Time Elapsed: 4418.89 seconds
# Episode 405	Average Score: 7.18	Time Elapsed: 4432.36 seconds
# Episode 406	Average Score: 7.21	Time Elapsed: 4445.36 seconds
# Episode 407	Average Score: 7.30	Time Elapsed: 4457.86 seconds
# Episode 408	Average Score: 7.33	Time Elapsed: 4470.06 seconds
# Episode 409	Average Score: 7.36	Time Elapsed: 4482.26 seconds
# Episode 410	Average Score: 7.41	Time Elapsed: 4494.26 seconds
# Episode 411	Average Score: 7.43	Time Elapsed: 4506.38 seconds
# Episode 412	Average Score: 7.49	Time Elapsed: 4518.66 seconds
# Episode 413	Average Score: 7.49	Time Elapsed: 4532.26 seconds
# Episode 414	Average Score: 7.47	Time Elapsed: 4546.19 seconds
# Episode 415	Average Score: 7.51	Time Elapsed: 4560.16 seconds
# Episode 416	Average Score: 7.50	Time Elapsed: 4573.76 seconds
# Episode 417	Average Score: 7.51	Time Elapsed: 4586.56 seconds
# Episode 418	Average Score: 7.47	Time Elapsed: 4600.78 seconds
# Episode 419	Average Score: 7.45	Time Elapsed: 4615.16 seconds
# Episode 420	Average Score: 7.51	Time Elapsed: 4628.58 seconds
# Episode 421	Average Score: 7.54	Time Elapsed: 4641.90 seconds
# Episode 422	Average Score: 7.50	Time Elapsed: 4655.46 seconds
# Episode 423	Average Score: 7.53	Time Elapsed: 4669.26 seconds
# Episode 424	Average Score: 7.53	Time Elapsed: 4682.20 seconds
# Episode 425	Average Score: 7.63	Time Elapsed: 4694.10 seconds
# Episode 426	Average Score: 7.67	Time Elapsed: 4706.56 seconds
# Episode 427	Average Score: 7.67	Time Elapsed: 4719.00 seconds
# Episode 428	Average Score: 7.72	Time Elapsed: 4731.40 seconds
# Episode 429	Average Score: 7.73	Time Elapsed: 4743.88 seconds
# Episode 430	Average Score: 7.67	Time Elapsed: 4755.56 seconds
# Episode 431	Average Score: 7.68	Time Elapsed: 4767.56 seconds
# Episode 432	Average Score: 7.69	Time Elapsed: 4780.60 seconds
# Episode 433	Average Score: 7.76	Time Elapsed: 4793.59 seconds
# Episode 434	Average Score: 7.73	Time Elapsed: 4805.46 seconds
# Episode 435	Average Score: 7.75	Time Elapsed: 4817.90 seconds
# Episode 436	Average Score: 7.68	Time Elapsed: 4830.06 seconds
# Episode 437	Average Score: 7.73	Time Elapsed: 4842.86 seconds
# Episode 438	Average Score: 7.78	Time Elapsed: 4855.50 seconds
# Episode 439	Average Score: 7.81	Time Elapsed: 4867.66 seconds
# Episode 440	Average Score: 7.85	Time Elapsed: 4879.96 seconds
# Episode 441	Average Score: 7.93	Time Elapsed: 4892.16 seconds
# Episode 442	Average Score: 8.05	Time Elapsed: 4904.36 seconds
# Episode 443	Average Score: 8.14	Time Elapsed: 4916.96 seconds
# Episode 444	Average Score: 8.17	Time Elapsed: 4929.17 seconds
# Episode 445	Average Score: 8.24	Time Elapsed: 4941.07 seconds
# Episode 446	Average Score: 8.32	Time Elapsed: 4953.16 seconds
# Episode 447	Average Score: 8.34	Time Elapsed: 4965.46 seconds
# Episode 448	Average Score: 8.34	Time Elapsed: 4977.70 seconds
# Episode 449	Average Score: 8.42	Time Elapsed: 4989.69 seconds
# Episode 450	Average Score: 8.40	Time Elapsed: 5001.50 seconds
# Episode 451	Average Score: 8.45	Time Elapsed: 5013.46 seconds
# Episode 452	Average Score: 8.47	Time Elapsed: 5025.60 seconds
# Episode 453	Average Score: 8.62	Time Elapsed: 5037.70 seconds
# Episode 454	Average Score: 8.65	Time Elapsed: 5050.10 seconds
# Episode 455	Average Score: 8.69	Time Elapsed: 5061.96 seconds
# Episode 456	Average Score: 8.77	Time Elapsed: 5073.57 seconds
# Episode 457	Average Score: 8.80	Time Elapsed: 5085.56 seconds
# Episode 458	Average Score: 8.84	Time Elapsed: 5098.20 seconds
# Episode 459	Average Score: 8.81	Time Elapsed: 5110.69 seconds
# Episode 460	Average Score: 8.82	Time Elapsed: 5122.36 seconds
# Episode 461	Average Score: 8.91	Time Elapsed: 5134.66 seconds
# Episode 462	Average Score: 8.93	Time Elapsed: 5146.56 seconds
# Episode 463	Average Score: 8.90	Time Elapsed: 5158.46 seconds
# Episode 464	Average Score: 8.98	Time Elapsed: 5170.40 seconds
# Episode 465	Average Score: 9.00	Time Elapsed: 5182.29 seconds
# Episode 466	Average Score: 8.96	Time Elapsed: 5193.90 seconds
# Episode 467	Average Score: 8.91	Time Elapsed: 5206.17 seconds
# Episode 468	Average Score: 8.98	Time Elapsed: 5218.17 seconds
# Episode 469	Average Score: 9.04	Time Elapsed: 5229.76 seconds
# Episode 470	Average Score: 9.11	Time Elapsed: 5241.66 seconds
# Episode 471	Average Score: 9.15	Time Elapsed: 5253.60 seconds
# Episode 472	Average Score: 9.15	Time Elapsed: 5265.20 seconds
# Episode 473	Average Score: 9.21	Time Elapsed: 5276.96 seconds
# Episode 474	Average Score: 9.23	Time Elapsed: 5288.96 seconds
# Episode 475	Average Score: 9.21	Time Elapsed: 5300.89 seconds
# Episode 476	Average Score: 9.32	Time Elapsed: 5312.96 seconds
# Episode 477	Average Score: 9.48	Time Elapsed: 5324.66 seconds
# Episode 478	Average Score: 9.57	Time Elapsed: 5337.09 seconds
# Episode 479	Average Score: 9.61	Time Elapsed: 5348.69 seconds
# Episode 480	Average Score: 9.64	Time Elapsed: 5360.29 seconds
# Episode 481	Average Score: 9.65	Time Elapsed: 5372.29 seconds
# Episode 482	Average Score: 9.67	Time Elapsed: 5385.16 seconds
# Episode 483	Average Score: 9.66	Time Elapsed: 5397.86 seconds
# Episode 484	Average Score: 9.71	Time Elapsed: 5410.30 seconds
# Episode 485	Average Score: 9.74	Time Elapsed: 5422.90 seconds
# Episode 486	Average Score: 9.75	Time Elapsed: 5434.96 seconds
# Episode 487	Average Score: 9.79	Time Elapsed: 5446.90 seconds
# Episode 488	Average Score: 9.86	Time Elapsed: 5458.50 seconds
# Episode 489	Average Score: 9.84	Time Elapsed: 5470.48 seconds
# Episode 490	Average Score: 9.86	Time Elapsed: 5482.30 seconds
# Episode 491	Average Score: 9.84	Time Elapsed: 5494.19 seconds
# Episode 492	Average Score: 9.86	Time Elapsed: 5506.06 seconds
# Episode 493	Average Score: 9.84	Time Elapsed: 5518.96 seconds
# Episode 494	Average Score: 9.80	Time Elapsed: 5533.56 seconds
# Episode 495	Average Score: 9.86	Time Elapsed: 5547.76 seconds
# Episode 496	Average Score: 9.93	Time Elapsed: 5561.76 seconds
# Episode 497	Average Score: 10.00	Time Elapsed: 5575.56 seconds
# Episode 498	Average Score: 10.00	Time Elapsed: 5590.16 seconds
# Episode 499	Average Score: 9.93	Time Elapsed: 5604.96 seconds
# Episode 500	Average Score: 9.91	Time Elapsed: 5618.96 seconds
#
# Episode 500	Average Score: 9.91
#
# Episode 501	Average Score: 9.89	Time Elapsed: 5633.66 seconds
# Episode 502	Average Score: 9.89	Time Elapsed: 5647.66 seconds
# Episode 503	Average Score: 9.93	Time Elapsed: 5660.96 seconds
# Episode 504	Average Score: 9.97	Time Elapsed: 5675.06 seconds
# Episode 505	Average Score: 10.06	Time Elapsed: 5688.18 seconds
# Episode 506	Average Score: 10.13	Time Elapsed: 5702.96 seconds
# Episode 507	Average Score: 10.09	Time Elapsed: 5717.76 seconds
# Episode 508	Average Score: 10.16	Time Elapsed: 5732.46 seconds
# Episode 509	Average Score: 10.09	Time Elapsed: 5746.40 seconds
# Episode 510	Average Score: 10.11	Time Elapsed: 5760.99 seconds
# Episode 511	Average Score: 10.20	Time Elapsed: 5775.46 seconds
# Episode 512	Average Score: 10.18	Time Elapsed: 5789.96 seconds
# Episode 513	Average Score: 10.16	Time Elapsed: 5804.66 seconds
# Episode 514	Average Score: 10.16	Time Elapsed: 5818.66 seconds
# Episode 515	Average Score: 10.20	Time Elapsed: 5832.66 seconds
# Episode 516	Average Score: 10.25	Time Elapsed: 5846.86 seconds
# Episode 517	Average Score: 10.31	Time Elapsed: 5861.16 seconds
# Episode 518	Average Score: 10.51	Time Elapsed: 5875.06 seconds
# Episode 519	Average Score: 10.49	Time Elapsed: 5888.07 seconds
# Episode 520	Average Score: 10.56	Time Elapsed: 5899.89 seconds
# Episode 521	Average Score: 10.56	Time Elapsed: 5912.00 seconds
# Episode 522	Average Score: 10.62	Time Elapsed: 5924.26 seconds
# Episode 523	Average Score: 10.66	Time Elapsed: 5936.36 seconds
# Episode 524	Average Score: 10.60	Time Elapsed: 5948.80 seconds
# Episode 525	Average Score: 10.57	Time Elapsed: 5961.70 seconds
# Episode 526	Average Score: 10.56	Time Elapsed: 5974.56 seconds
# Episode 527	Average Score: 10.60	Time Elapsed: 5986.66 seconds
# Episode 528	Average Score: 10.65	Time Elapsed: 5999.00 seconds
# Episode 529	Average Score: 10.74	Time Elapsed: 6010.97 seconds
# Episode 530	Average Score: 10.84	Time Elapsed: 6023.36 seconds
# Episode 531	Average Score: 10.88	Time Elapsed: 6036.16 seconds
# Episode 532	Average Score: 10.86	Time Elapsed: 6049.08 seconds
# Episode 533	Average Score: 10.85	Time Elapsed: 6061.96 seconds
# Episode 534	Average Score: 10.94	Time Elapsed: 6074.96 seconds
# Episode 535	Average Score: 11.11	Time Elapsed: 6087.77 seconds
# Episode 536	Average Score: 11.22	Time Elapsed: 6099.40 seconds
# Episode 537	Average Score: 11.23	Time Elapsed: 6113.46 seconds
# Episode 538	Average Score: 11.18	Time Elapsed: 6127.56 seconds
# Episode 539	Average Score: 11.11	Time Elapsed: 6141.28 seconds
# Episode 540	Average Score: 11.24	Time Elapsed: 6154.56 seconds
# Episode 541	Average Score: 11.23	Time Elapsed: 6168.86 seconds
# Episode 542	Average Score: 11.18	Time Elapsed: 6182.06 seconds
# Episode 543	Average Score: 11.21	Time Elapsed: 6195.00 seconds
# Episode 544	Average Score: 11.28	Time Elapsed: 6208.66 seconds
# Episode 545	Average Score: 11.36	Time Elapsed: 6222.86 seconds
# Episode 546	Average Score: 11.32	Time Elapsed: 6236.66 seconds
# Episode 547	Average Score: 11.43	Time Elapsed: 6249.09 seconds
# Episode 548	Average Score: 11.48	Time Elapsed: 6262.56 seconds
# Episode 549	Average Score: 11.50	Time Elapsed: 6276.06 seconds
# Episode 550	Average Score: 11.58	Time Elapsed: 6289.06 seconds
# Episode 551	Average Score: 11.54	Time Elapsed: 6302.56 seconds
# Episode 552	Average Score: 11.55	Time Elapsed: 6316.06 seconds
# Episode 553	Average Score: 11.56	Time Elapsed: 6328.16 seconds
# Episode 554	Average Score: 11.60	Time Elapsed: 6342.08 seconds
# Episode 555	Average Score: 11.62	Time Elapsed: 6355.00 seconds
# Episode 556	Average Score: 11.49	Time Elapsed: 6367.80 seconds
# Episode 557	Average Score: 11.62	Time Elapsed: 6380.76 seconds
# Episode 558	Average Score: 11.71	Time Elapsed: 6394.06 seconds
# Episode 559	Average Score: 11.87	Time Elapsed: 6407.46 seconds
# Episode 560	Average Score: 11.82	Time Elapsed: 6421.66 seconds
# Episode 561	Average Score: 11.85	Time Elapsed: 6434.06 seconds
# Episode 562	Average Score: 11.88	Time Elapsed: 6446.30 seconds
# Episode 563	Average Score: 11.98	Time Elapsed: 6459.06 seconds
# Episode 564	Average Score: 12.02	Time Elapsed: 6472.00 seconds
# Episode 565	Average Score: 12.12	Time Elapsed: 6486.66 seconds
# Episode 566	Average Score: 12.12	Time Elapsed: 6501.16 seconds
# Episode 567	Average Score: 12.07	Time Elapsed: 6515.30 seconds
# Episode 568	Average Score: 12.06	Time Elapsed: 6529.47 seconds
# Episode 569	Average Score: 11.96	Time Elapsed: 6541.49 seconds
# Episode 570	Average Score: 12.00	Time Elapsed: 6553.76 seconds
# Episode 571	Average Score: 12.01	Time Elapsed: 6567.27 seconds
# Episode 572	Average Score: 12.07	Time Elapsed: 6578.98 seconds
# Episode 573	Average Score: 12.11	Time Elapsed: 6591.10 seconds
# Episode 574	Average Score: 12.18	Time Elapsed: 6603.26 seconds
# Episode 575	Average Score: 12.26	Time Elapsed: 6614.97 seconds
# Episode 576	Average Score: 12.25	Time Elapsed: 6627.06 seconds
# Episode 577	Average Score: 12.23	Time Elapsed: 6640.29 seconds
# Episode 578	Average Score: 12.16	Time Elapsed: 6653.36 seconds
# Episode 579	Average Score: 12.15	Time Elapsed: 6666.66 seconds
# Episode 580	Average Score: 12.14	Time Elapsed: 6678.89 seconds
# Episode 581	Average Score: 12.13	Time Elapsed: 6691.36 seconds
# Episode 582	Average Score: 12.11	Time Elapsed: 6703.60 seconds
# Episode 583	Average Score: 12.16	Time Elapsed: 6717.36 seconds
# Episode 584	Average Score: 12.22	Time Elapsed: 6730.66 seconds
# Episode 585	Average Score: 12.28	Time Elapsed: 6743.08 seconds
# Episode 586	Average Score: 12.32	Time Elapsed: 6754.76 seconds
# Episode 587	Average Score: 12.27	Time Elapsed: 6766.36 seconds
# Episode 588	Average Score: 12.31	Time Elapsed: 6778.76 seconds
# Episode 589	Average Score: 12.31	Time Elapsed: 6790.86 seconds
# Episode 590	Average Score: 12.21	Time Elapsed: 6802.96 seconds
# Episode 591	Average Score: 12.28	Time Elapsed: 6814.60 seconds
# Episode 592	Average Score: 12.34	Time Elapsed: 6826.20 seconds
# Episode 593	Average Score: 12.43	Time Elapsed: 6837.80 seconds
# Episode 594	Average Score: 12.44	Time Elapsed: 6849.29 seconds
# Episode 595	Average Score: 12.47	Time Elapsed: 6860.90 seconds
# Episode 596	Average Score: 12.48	Time Elapsed: 6872.36 seconds
# Episode 597	Average Score: 12.52	Time Elapsed: 6884.16 seconds
# Episode 598	Average Score: 12.59	Time Elapsed: 6896.96 seconds
# Episode 599	Average Score: 12.72	Time Elapsed: 6908.86 seconds
# Episode 600	Average Score: 12.79	Time Elapsed: 6920.29 seconds
#
# Episode 600	Average Score: 12.79
#
# Episode 601	Average Score: 12.89	Time Elapsed: 6932.16 seconds
# Episode 602	Average Score: 12.94	Time Elapsed: 6944.21 seconds
# Episode 603	Average Score: 12.94	Time Elapsed: 6955.96 seconds
# Episode 604	Average Score: 12.92	Time Elapsed: 6967.80 seconds
# Episode 605	Average Score: 12.97	Time Elapsed: 6979.30 seconds
# Episode 606	Average Score: 12.99	Time Elapsed: 6991.38 seconds
# Episode 607	Average Score: 13.09	Time Elapsed: 7004.36 seconds
#
# Environment solved in 607 episodes!	Average Score: 13.09

# %%
# Final plot
plot_training_progress(scores, avg_scores, i_episode)

# %% [markdown]
# ## Section 9: Closing the Environment

# %%
# Closes the Unity environment to free resources.
env.close()
